#        [  -1.,   -1.,  327.,  140.,  343.,  141.,  346.,  163.,  345.,
#          172.,  314.,  140.,  312.,  163.,  311.,  181.,  337.,  178.,
#          337.,  200.,  334.,  222.,  324.,  179.,  333.,  200.,  333.,
#          221.,   -1.,   -1.,   -1.,   -1.,  335.,  126.,  324.,  125.],
#        [  -1.,   -1.,  344.,  115.,  354.,  115.,  356.,  129.,  356.,
#          140.,  334.,  114.,  328.,  129.,  326.,  144.,  347.,  141.,
#          347.,  161.,  346.,  180.,  336.,  141.,  336.,  160.,  336.,
#          180.,   -1.,   -1.,   -1.,   -1.,  348.,  103.,  341.,   99.],
#        [ 322.,   95.,  332.,  100.,  336.,   98.,  342.,  115.,  339.,
#          126.,  325.,  102.,  324.,  115.,  323.,  127.,  336.,  126.,
#          335.,  144.,  337.,  160.,  327.,  127.,  327.,  144.,  332.,
#          159.,   -1.,   -1.,  322.,   93.,  333.,   93.,  325.,   91.],
#        [ 288.,   88.,  295.,   95.,  303.,   94.,  307.,  105.,  305.,
#          113.,  292.,   96.,  290.,  108.,  289.,  117.,  304.,  116.,
#          303.,  134.,  304.,  149.,  295.,  117.,  293.,  131.,  294.,
#          148.,   -1.,   -1.,  288.,   86.,  295.,   85.,  291.,   86.]])

# %%
dat2 = np.arange(20).reshape((4,5))
dat2[1][1] = -1
dat2[0][3] = dat2[1][3] = dat2[2][3] = -1
dat2
# Out:
# array([[ 0,  1,  2, -1,  4],
#        [ 5, -1,  7, -1,  9],
#        [10, 11, 12, -1, 14],
#        [15, 16, 17, 18, 19]])

# %%
#dat = dat2.copy()

#[i[0] for i in np.where(dat==-1)]

while True:
    nan_index = np.where(dat==-1)
    if np.shape(nan_index) == (2,0):
        break
    loss_index = [i[0] for i in nan_index]
    
    y0 = y1 = loss_index[0]
    x = loss_index[1]
    range_count = 0
    while True:
        range_count += 1
        y0 -= 1
        try:
            before_val = dat[y0,x]
        except IndexError as err:
            print(err)
            dat[y1+1][x] = dat[y][x]
            break
        if before_val > 0:
            break
    
    while True:
        range_count += 1
        y1 += 1
        try:
            after_val = dat[y1,x]
        except IndexError as err:
            print(err)
            dat[y1-1][x] = dat[y][x]
            break
        if after_val > 0:
            break
            
    #t = y1 - y0 - 1
    for i in range(y0+1, y1):
        try:
            print("orig_val", dat[i][x])
            print("y0 i y1 range_count i", y0, i, y1, range_count, i)
            print("y0 i y1 range_count i", dat[y0][x] ,(range_count-i) ,dat[y1][x] ,(i))
            print("result", dat[y0][x] *(range_count-i-1) + dat[y1][x] * (i+1))
        #try:
            dat[i][x] = (dat[y0][x] *(range_count-i) + dat[y1][x] * i) \
                / range_count
        except IndexError as err:
            print(dat)
            np.savetxt("calibrate_test.csv", dat, delimiter=",")
        
    print("-------------------")
    
    #dat[loss_index[0]][loss_index[1]] = 1

print("org", dat2)
print("dat", dat)
# Out:
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 1, 2, 4, 3, 2)
# ('y0 i y1 range_count i', 283.0, 1, 252.0, 2)
# ('result', 756.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 1, 3, 4, 3, 3)
# ('y0 i y1 range_count i', 283.0, 0, 252.0, 3)
# ('result', 725.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 1, 2, 4, 3, 2)
# ('y0 i y1 range_count i', 108.0, 1, 312.0, 2)
# ('result', 936.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 1, 3, 4, 3, 3)
# ('y0 i y1 range_count i', 108.0, 0, 312.0, 3)
# ('result', 1140.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 3, 4, 5, 2, 4)
# ('y0 i y1 range_count i', 249.0, -2, 377.0, 4)
# ('result', 1138.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 3, 4, 5, 2, 4)
# ('y0 i y1 range_count i', 232.0, -2, 264.0, 4)
# ('result', 624.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 10, 6, 5)
# ('y0 i y1 range_count i', 271.0, 1, 324.0, 5)
# ('result', 1944.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 10, 6, 6)
# ('y0 i y1 range_count i', 271.0, 0, 324.0, 6)
# ('result', 1997.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 10, 6, 7)
# ('y0 i y1 range_count i', 271.0, -1, 324.0, 7)
# ('result', 2050.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 8, 10, 6, 8)
# ('y0 i y1 range_count i', 271.0, -2, 324.0, 8)
# ('result', 2103.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 9, 10, 6, 9)
# ('y0 i y1 range_count i', 271.0, -3, 324.0, 9)
# ('result', 2156.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 10, 6, 5)
# ('y0 i y1 range_count i', 311.0, 1, 86.0, 5)
# ('result', 516.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 10, 6, 6)
# ('y0 i y1 range_count i', 311.0, 0, 86.0, 6)
# ('result', 291.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 10, 6, 7)
# ('y0 i y1 range_count i', 311.0, -1, 86.0, 7)
# ('result', 66.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 8, 10, 6, 8)
# ('y0 i y1 range_count i', 311.0, -2, 86.0, 8)
# ('result', -159.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 9, 10, 6, 9)
# ('y0 i y1 range_count i', 311.0, -3, 86.0, 9)
# ('result', -384.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 8, 4, 5)
# ('y0 i y1 range_count i', 292.0, -1, 382.0, 5)
# ('result', 1708.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 8, 4, 6)
# ('y0 i y1 range_count i', 292.0, -2, 382.0, 6)
# ('result', 1798.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 8, 4, 7)
# ('y0 i y1 range_count i', 292.0, -3, 382.0, 7)
# ('result', 1888.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 8, 4, 5)
# ('y0 i y1 range_count i', 367.0, -1, 148.0, 5)
# ('result', 154.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 8, 4, 6)
# ('y0 i y1 range_count i', 367.0, -2, 148.0, 6)
# ('result', -65.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 8, 4, 7)
# ('y0 i y1 range_count i', 367.0, -3, 148.0, 7)
# ('result', -284.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 304.0, -3, 364.0, 5)
# ('result', 968.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 330.0, -3, 247.0, 5)
# ('result', 162.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 284.0, -3, 383.0, 5)
# ('result', 1162.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 370.0, -3, 280.0, 5)
# ('result', 200.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 302.0, -3, 377.0, 5)
# ('result', 1054.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 367.0, -3, 300.0, 5)
# ('result', 332.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 310.0, -3, 378.0, 5)
# ('result', 1028.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 342.0, -3, 285.0, 5)
# ('result', 342.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 315.0, -3, 377.0, 5)
# ('result', 1002.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 6, 2, 5)
# ('y0 i y1 range_count i', 353.0, -3, 307.0, 5)
# ('result', 430.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 10, 6, 5)
# ('y0 i y1 range_count i', 263.0, 1, 325.0, 5)
# ('result', 1950.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 10, 6, 6)
# ('y0 i y1 range_count i', 263.0, 0, 325.0, 6)
# ('result', 2012.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 10, 6, 7)
# ('y0 i y1 range_count i', 263.0, -1, 325.0, 7)
# ('result', 2074.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 8, 10, 6, 8)
# ('y0 i y1 range_count i', 263.0, -2, 325.0, 8)
# ('result', 2136.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 9, 10, 6, 9)
# ('y0 i y1 range_count i', 263.0, -3, 325.0, 9)
# ('result', 2198.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 10, 6, 5)
# ('y0 i y1 range_count i', 310.0, 1, 85.0, 5)
# ('result', 510.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 10, 6, 6)
# ('y0 i y1 range_count i', 310.0, 0, 85.0, 6)
# ('result', 285.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 10, 6, 7)
# ('y0 i y1 range_count i', 310.0, -1, 85.0, 7)
# ('result', 60.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 8, 10, 6, 8)
# ('y0 i y1 range_count i', 310.0, -2, 85.0, 8)
# ('result', -165.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 9, 10, 6, 9)
# ('y0 i y1 range_count i', 310.0, -3, 85.0, 9)
# ('result', -390.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 10, 6, 5)
# ('y0 i y1 range_count i', 271.0, 1, 325.0, 5)
# ('result', 1950.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 10, 6, 6)
# ('y0 i y1 range_count i', 271.0, 0, 325.0, 6)
# ('result', 2004.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 10, 6, 7)
# ('y0 i y1 range_count i', 271.0, -1, 325.0, 7)
# ('result', 2058.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 8, 10, 6, 8)
# ('y0 i y1 range_count i', 271.0, -2, 325.0, 8)
# ('result', 2112.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 9, 10, 6, 9)
# ('y0 i y1 range_count i', 271.0, -3, 325.0, 9)
# ('result', 2166.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 5, 10, 6, 5)
# ('y0 i y1 range_count i', 307.0, 1, 85.0, 5)
# ('result', 510.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 6, 10, 6, 6)
# ('y0 i y1 range_count i', 307.0, 0, 85.0, 6)
# ('result', 288.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 7, 10, 6, 7)
# ('y0 i y1 range_count i', 307.0, -1, 85.0, 7)
# ('result', 66.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 8, 10, 6, 8)
# ('y0 i y1 range_count i', 307.0, -2, 85.0, 8)
# ('result', -156.0)
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 4, 9, 10, 6, 9)
# ('y0 i y1 range_count i', 307.0, -3, 85.0, 9)
# ('result', -378.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 9, 10, 11, 2, 10)
# ('y0 i y1 range_count i', 353.0, -8, 296.0, 10)
# ('result', 79.0)
# -------------------
# ('orig_val', -1.0)
# ('y0 i y1 range_count i', 9, 10, 11, 2, 10)
# ('y0 i y1 range_count i', 93.0, -8, 87.0, 10)
# ('result', 120.0)
# -------------------
# index 23 is out of bounds for axis 0 with size 23
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d70f6d70e9d5> in <module>()
#      31         except IndexError as err:
#      32             print(err)
# ---> 33             dat[y1-1][x] = dat[y][x]
#      34             break
#      35         if after_val > 0:
#
# NameError: name 'y' is not defined
